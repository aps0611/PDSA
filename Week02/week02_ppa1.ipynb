# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def combinationSort(LIST):
    L1 = sorted(LIST, key=lambda s: s[0])
    L2 = sorted(L1, key=lambda s: (s[0], -int(s[1:])))
    return L1, L2

# %%
LIST = ['d34', 'g54', 'd12', 'b87', 'g1', 'c65', 'g40', 'g5', 'd77']
combinationSort(LIST)
# Out:
# (['b87', 'c65', 'd34', 'd12', 'd77', 'g54', 'g1', 'g40', 'g5'],
#  ['b87', 'c65', 'd77', 'd34', 'd12', 'g54', 'g40', 'g5', 'g1'])
